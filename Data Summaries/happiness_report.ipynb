# %%
import json
import numpy as np
import pandas as pd
import statsmodels.api as sm

from itertools import combinations
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %% [markdown]
# #### import the data

# %%
happiness_df = pd.read_csv("../World Happiness Report.csv")
happiness_df.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                      0.718114    0.167652                   0.881686
# 1                      0.678896    0.190809                   0.850035
# 2                      0.600127    0.121316                   0.706766
# 3                      0.495901    0.163571                   0.731109
# 4                      0.530935    0.237588                   0.775620
#
#    Positive Affect  Negative Affect  Confidence In National Government
# 0         0.414297         0.258195                           0.612072
# 1         0.481421         0.237092                           0.611545
# 2         0.516907         0.275324                           0.299357
# 3         0.479835         0.267175                           0.307386
# 4         0.613513         0.267919                           0.435440

# %% [markdown]
# #### let's explore it a little bit...
#
# checking the correlation will allow us to see which variables are most commonly related. this allows us to check to see which things relate to "Life Ladder", and also which independent variables relate to each other.

# %%
happiness_df.corr(numeric_only=True)
# Out:
#                                        Year  Life Ladder  Log GDP Per Capita  \
# Year                               1.000000     0.045943            0.077772
# Life Ladder                        0.045943     1.000000            0.784871
# Log GDP Per Capita                 0.077772     0.784871            1.000000
# Social Support                    -0.029750     0.721663            0.683619
# Healthy Life Expectancy At Birth   0.163500     0.713493            0.818126
# Freedom To Make Life Choices       0.234105     0.534532            0.367560
# Generosity                         0.005726     0.181658           -0.000800
# Perceptions Of Corruption         -0.081358    -0.431569           -0.352884
# Positive Affect                    0.019182     0.518207            0.237986
# Negative Affect                    0.205369    -0.339992           -0.247560
# Confidence In National Government  0.012638    -0.081887           -0.188351
#
#                                    Social Support  \
# Year                                    -0.029750
# Life Ladder                              0.721663
# Log GDP Per Capita                       0.683619
# Social Support                           1.000000
# Healthy Life Expectancy At Birth         0.597682
# Freedom To Make Life Choices             0.409439
# Generosity                               0.068593
# Perceptions Of Corruption               -0.222584
# Positive Affect                          0.431139
# Negative Affect                         -0.441800
# Confidence In National Government       -0.169573
#
#                                    Healthy Life Expectancy At Birth  \
# Year                                                       0.163500
# Life Ladder                                                0.713493
# Log GDP Per Capita                                         0.818126
# Social Support                                             0.597682
# Healthy Life Expectancy At Birth                           1.000000
# Freedom To Make Life Choices                               0.373448
# Generosity                                                 0.010876
# Perceptions Of Corruption                                 -0.299055
# Positive Affect                                            0.223119
# Negative Affect                                           -0.140726
# Confidence In National Government                         -0.178003
#
#                                    Freedom To Make Life Choices  Generosity  \
# Year                                                   0.234105    0.005726
# Life Ladder                                            0.534532    0.181658
# Log GDP Per Capita                                     0.367560   -0.000800
# Social Support                                         0.409439    0.068593
# Healthy Life Expectancy At Birth                       0.373448    0.010876
# Freedom To Make Life Choices                           1.000000    0.325107
# Generosity                                             0.325107    1.000000
# Perceptions Of Corruption                             -0.476537   -0.279494
# Positive Affect                                        0.578752    0.307140
# Negative Affect                                       -0.275470   -0.080837
# Confidence In National Government                      0.408533    0.294399
#
#                                    Perceptions Of Corruption  Positive Affect  \
# Year                                               -0.081358         0.019182
# Life Ladder                                        -0.431569         0.518207
# Log GDP Per Capita                                 -0.352884         0.237986
# Social Support                                     -0.222584         0.431139
# Healthy Life Expectancy At Birth                   -0.299055         0.223119
# Freedom To Make Life Choices                       -0.476537         0.578752
# Generosity                                         -0.279494         0.307140
# Perceptions Of Corruption                           1.000000        -0.280620
# Positive Affect                                    -0.280620         1.000000
# Negative Affect                                     0.266267        -0.330236
# Confidence In National Government                  -0.460789         0.123241
#
#                                    Negative Affect  \
# Year                                      0.205369
# Life Ladder                              -0.339992
# Log GDP Per Capita                       -0.247560
# Social Support                           -0.441800
# Healthy Life Expectancy At Birth         -0.140726
# Freedom To Make Life Choices             -0.275470
# Generosity                               -0.080837
# Perceptions Of Corruption                 0.266267
# Positive Affect                          -0.330236
# Negative Affect                           1.000000
# Confidence In National Government        -0.125631
#
#                                    Confidence In National Government
# Year                                                        0.012638
# Life Ladder                                                -0.081887
# Log GDP Per Capita                                         -0.188351
# Social Support                                             -0.169573
# Healthy Life Expectancy At Birth                           -0.178003
# Freedom To Make Life Choices                                0.408533
# Generosity                                                  0.294399
# Perceptions Of Corruption                                  -0.460789
# Positive Affect                                             0.123241
# Negative Affect                                            -0.125631
# Confidence In National Government                           1.000000

# %% [markdown]
# we can also do a basic linear regression model with single variables to see what the R-value is of each indepedent variable against the dependent variable

# %%
happiness_df = happiness_df.dropna()
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numbers_df = happiness_df.select_dtypes(include=numerics)

# %%
score_dict = {}

for variable in numbers_df.columns:
    temp_df = numbers_df.copy()
    lr = linear_model.LinearRegression()
    lr.fit(temp_df[[variable]], temp_df["Life Ladder"])
    score_dict[variable] = {"score": lr.score(temp_df[[variable]], numbers_df["Life Ladder"])}

print(json.dumps(score_dict, indent=4))
# Out:
# {
#     "Year": {
#         "score": 0.0051478832185841705
#     },
#     "Life Ladder": {
#         "score": 1.0
#     },
#     "Log GDP Per Capita": {
#         "score": 0.6281698077144784
#     },
#     "Social Support": {
#         "score": 0.5192853987535683
#     },
#     "Healthy Life Expectancy At Birth": {
#         "score": 0.5404614758255641
#     },
#     "Freedom To Make Life Choices": {
#         "score": 0.2940861329423261
#     },
#     "Generosity": {
#         "score": 0.03753479127663817
#     },
#     "Perceptions Of Corruption": {
#         "score": 0.24222475409085542
#     },
#     "Positive Affect": {
#         "score": 0.26300717570566623
#     },
#     "Negative Affect": {
#         "score": 0.09594787291010276
#     },
#     "Confidence In National Government": {
#         "score": 0.0047124322248692785
#     },
#     "int": {
#         "score": 0.08155250752791565
#     }
# }

# %% [markdown]
# We can actually add the correlation to this now, too...

# %%
for variable in numbers_df.columns:
    lr = linear_model.LinearRegression()
    lr.fit(numbers_df[[variable]], numbers_df["Life Ladder"])
    score_dict[variable].update(
        {"correlation": numbers_df["Life Ladder"].corr(numbers_df[variable])}
    )

print(json.dumps(score_dict, indent=4))
# Out:
# {
#     "Year": {
#         "score": 0.0051478832185841705,
#         "correlation": 0.07174875064127634
#     },
#     "Life Ladder": {
#         "score": 1.0,
#         "correlation": 1.0
#     },
#     "Log GDP Per Capita": {
#         "score": 0.6281698077144784,
#         "correlation": 0.7925716420075085
#     },
#     "Social Support": {
#         "score": 0.5192853987535683,
#         "correlation": 0.7206145979326039
#     },
#     "Healthy Life Expectancy At Birth": {
#         "score": 0.5404614758255641,
#         "correlation": 0.7351608503079881
#     },
#     "Freedom To Make Life Choices": {
#         "score": 0.2940861329423261,
#         "correlation": 0.5422970891885057
#     },
#     "Generosity": {
#         "score": 0.03753479127663817,
#         "correlation": 0.1937389771745434
#     },
#     "Perceptions Of Corruption": {
#         "score": 0.24222475409085542,
#         "correlation": -0.49216334086444846
#     },
#     "Positive Affect": {
#         "score": 0.26300717570566623,
#         "correlation": 0.5128422522624927
#     },
#     "Negative Affect": {
#         "score": 0.09594787291010276,
#         "correlation": -0.3097545365448305
#     },
#     "Confidence In National Government": {
#         "score": 0.0047124322248692785,
#         "correlation": -0.0686471574420167
#     },
#     "int": {
#         "score": 0.08155250752791565,
#         "correlation": -0.28557399658917776
#     }
# }

# %% [markdown]
# let's try these variables to start...

# %%
columns = [
    "Positive Affect", 
    "Freedom To Make Life Choices",
    "Healthy Life Expectancy At Birth",
    "Social Support",
    "Log GDP Per Capita",
]

# %% [markdown]
# here are some easy ways to train and test the models!

# %%
def train_model(df, cols):
    X = df[cols]
    y = df["Life Ladder"]
    model = sm.OLS(y, X).fit()
    return model

def test_model(df, cols, model):
    X = df[cols]
    df_p = df
    df_p = df_p.assign(predicted_life_ladder=model.predict(X))
    df_p = df_p.assign(error=df_p.predicted_life_ladder - df_p["Life Ladder"])
    return df_p

def compute_rmse(df):
    return np.sqrt(np.square(df.error).mean())

# %% [markdown]
# lets split the data into a train and test dataset

# %%
train_df, test_df = train_test_split(happiness_df, test_size=0.75, random_state=58)

# %% [markdown]
# let's try training the model now!

# %%
model = train_model(train_df, columns)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Life Ladder   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              5897.
# Date:                Fri, 19 May 2023   Prob (F-statistic):                        0.00
# Time:                        18:39:45   Log-Likelihood:                         -420.58
# No. Observations:                 420   AIC:                                      851.2
# Df Residuals:                     415   BIC:                                      871.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Positive Affect                      0.8214      0.360      2.281      0.023       0.114       1.529
# Freedom To Make Life Choices         0.9881      0.284      3.475      0.001       0.429       1.547
# Healthy Life Expectancy At Birth    -0.0258      0.008     -3.045      0.002      -0.042      -0.009
# Social Support                       1.7565      0.397      4.422      0.000       0.976       2.537
# Log GDP Per Capita                   0.4751      0.061      7.843      0.000       0.356       0.594
# ==============================================================================
# Omnibus:                        2.228   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                2.126
# Skew:                          -0.174   Prob(JB):                        0.345
# Kurtosis:                       3.020   Cond. No.                         888.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
predict_df = test_model(train_df, columns, model)

print("RMSE:", compute_rmse(predict_df))
print("Correlation:", predict_df["Life Ladder"].corr(predict_df["predicted_life_ladder"]))
# Out:
# RMSE: 0.6586462588002616
# Correlation: 0.8544157928721342

# %% [markdown]
# 85% correlation is really good! we can try doing some feature engineering to see if we can get anything better
#
# feature engineering is usually manipulating the independent variables you have access to, to see if combining or dividing them yields better variables
#
# let's try a brute force method here

# %%
columns_list = numbers_df.columns
interactions = list(combinations(columns_list, 2))
interactions
# Out:
# [('Year', 'Life Ladder'),
#  ('Year', 'Log GDP Per Capita'),
#  ('Year', 'Social Support'),
#  ('Year', 'Healthy Life Expectancy At Birth'),
#  ('Year', 'Freedom To Make Life Choices'),
#  ('Year', 'Generosity'),
#  ('Year', 'Perceptions Of Corruption'),
#  ('Year', 'Positive Affect'),
#  ('Year', 'Negative Affect'),
#  ('Year', 'Confidence In National Government'),
#  ('Year', 'int'),
#  ('Life Ladder', 'Log GDP Per Capita'),
#  ('Life Ladder', 'Social Support'),
#  ('Life Ladder', 'Healthy Life Expectancy At Birth'),
#  ('Life Ladder', 'Freedom To Make Life Choices'),
#  ('Life Ladder', 'Generosity'),
#  ('Life Ladder', 'Perceptions Of Corruption'),
#  ('Life Ladder', 'Positive Affect'),
#  ('Life Ladder', 'Negative Affect'),
#  ('Life Ladder', 'Confidence In National Government'),
#  ('Life Ladder', 'int'),
#  ('Log GDP Per Capita', 'Social Support'),
#  ('Log GDP Per Capita', 'Healthy Life Expectancy At Birth'),
#  ('Log GDP Per Capita', 'Freedom To Make Life Choices'),
#  ('Log GDP Per Capita', 'Generosity'),
#  ('Log GDP Per Capita', 'Perceptions Of Corruption'),
#  ('Log GDP Per Capita', 'Positive Affect'),
#  ('Log GDP Per Capita', 'Negative Affect'),
#  ('Log GDP Per Capita', 'Confidence In National Government'),
#  ('Log GDP Per Capita', 'int'),
#  ('Social Support', 'Healthy Life Expectancy At Birth'),
#  ('Social Support', 'Freedom To Make Life Choices'),
#  ('Social Support', 'Generosity'),
#  ('Social Support', 'Perceptions Of Corruption'),
#  ('Social Support', 'Positive Affect'),
#  ('Social Support', 'Negative Affect'),
#  ('Social Support', 'Confidence In National Government'),
#  ('Social Support', 'int'),
#  ('Healthy Life Expectancy At Birth', 'Freedom To Make Life Choices'),
#  ('Healthy Life Expectancy At Birth', 'Generosity'),
#  ('Healthy Life Expectancy At Birth', 'Perceptions Of Corruption'),
#  ('Healthy Life Expectancy At Birth', 'Positive Affect'),
#  ('Healthy Life Expectancy At Birth', 'Negative Affect'),
#  ('Healthy Life Expectancy At Birth', 'Confidence In National Government'),
#  ('Healthy Life Expectancy At Birth', 'int'),
#  ('Freedom To Make Life Choices', 'Generosity'),
#  ('Freedom To Make Life Choices', 'Perceptions Of Corruption'),
#  ('Freedom To Make Life Choices', 'Positive Affect'),
#  ('Freedom To Make Life Choices', 'Negative Affect'),
#  ('Freedom To Make Life Choices', 'Confidence In National Government'),
#  ('Freedom To Make Life Choices', 'int'),
#  ('Generosity', 'Perceptions Of Corruption'),
#  ('Generosity', 'Positive Affect'),
#  ('Generosity', 'Negative Affect'),
#  ('Generosity', 'Confidence In National Government'),
#  ('Generosity', 'int'),
#  ('Perceptions Of Corruption', 'Positive Affect'),
#  ('Perceptions Of Corruption', 'Negative Affect'),
#  ('Perceptions Of Corruption', 'Confidence In National Government'),
#  ('Perceptions Of Corruption', 'int'),
#  ('Positive Affect', 'Negative Affect'),
#  ('Positive Affect', 'Confidence In National Government'),
#  ('Positive Affect', 'int'),
#  ('Negative Affect', 'Confidence In National Government'),
#  ('Negative Affect', 'int'),
#  ('Confidence In National Government', 'int')]

# %%
y = numbers_df["Life Ladder"]

for variable in interactions:
   temp_df = numbers_df.copy()
   var_1 = variable[0]
   var_2 = variable[1]
   temp_df['int'] = temp_df[var_1] * temp_df[var_2]
   lr1 = linear_model.LinearRegression()
   lr1.fit(temp_df[['int']], y)
   score_dict[f"{var_1} x {var_2}"] = {"score": lr1.score(temp_df[['int']], y)}
   score_dict[f"{var_1} x {var_2}"].update({"correlation": temp_df['int'].corr(y)})
   numbers_df[f"{var_1} x {var_2}"] = temp_df['int']

print(json.dumps(score_dict, indent=4))
# Out:
# {
#     "Year": {
#         "score": 0.0051478832185841705,
#         "correlation": 0.07174875064127634,
#         "combined": 0.038448316929930254
#     },
#     "Life Ladder": {
#         "score": 1.0,
#         "correlation": 1.0,
#         "combined": 1.0
#     },
#     "Log GDP Per Capita": {
#         "score": 0.6281698077144784,
#         "correlation": 0.7925716420075085,
#         "combined": 0.7103707248609934
#     },
#     "Social Support": {
#         "score": 0.5192853987535683,
#         "correlation": 0.7206145979326039,
#         "combined": 0.6199499983430861
#     },
#     "Healthy Life Expectancy At Birth": {
#         "score": 0.5404614758255641,
#         "correlation": 0.7351608503079881,
#         "combined": 0.6378111630667761
#     },
#     "Freedom To Make Life Choices": {
#         "score": 0.2940861329423261,
#         "correlation": 0.5422970891885057,
#         "combined": 0.4181916110654159
#     },
#     "Generosity": {
#         "score": 0.03753479127663817,
#         "correlation": 0.1937389771745434,
#         "combined": 0.11563688422559078
#     },
#     "Perceptions Of Corruption": {
#         "score": 0.24222475409085542,
#         "correlation": -0.49216334086444846,
#         "combined": -0.12496929338679652
#     },
#     "Positive Affect": {
#         "score": 0.26300717570566623,
#         "correlation": 0.5128422522624927,
#         "combined": 0.38792471398407946
#     },
#     "Negative Affect": {
#         "score": 0.09594787291010276,
#         "correlation": -0.3097545365448305,
#         "combined": -0.10690333181736386
#     },
#     "Confidence In National Government": {
#         "score": 0.0047124322248692785,
#         "correlation": -0.0686471574420167,
#         "combined": -0.03196736260857371
#     },
#     "int": {
#         "score": 0.08155250752791565,
#         "correlation": -0.28557399658917776,
#         "combined": -0.10201074453063105
#     },
#     "Year x Life Ladder": {
#         "score": 0.9998865402394389,
#         "correlation": 0.9999432685104888
#     },
#     "Year x Log GDP Per Capita": {
#         "score": 0.6277278908179801,
#         "correlation": 0.7922928062389435
#     },
#     "Year x Social Support": {
#         "score": 0.5207470851330853,
#         "correlation": 0.7216280795070857
#     },
#     "Year x Healthy Life Expectancy At Birth": {
#         "score": 0.5388578409747056,
#         "correlation": 0.7340693706828433
#     },
#     "Year x Freedom To Make Life Choices": {
#         "score": 0.293381458279405,
#         "correlation": 0.5416469867722011
#     },
#     "Year x Generosity": {
#         "score": 0.03746313986111449,
#         "correlation": 0.19355397144237216
#     },
#     "Year x Perceptions Of Corruption": {
#         "score": 0.24197590567307103,
#         "correlation": -0.4919104650981427
#     },
#     "Year x Positive Affect": {
#         "score": 0.2638460798800476,
#         "correlation": 0.5136594979945837
#     },
#     "Year x Negative Affect": {
#         "score": 0.09544999676760724,
#         "correlation": -0.3089498288842497
#     },
#     "Year x Confidence In National Government": {
#         "score": 0.0046634937229093065,
#         "correlation": -0.06828977758720077
#     },
#     "Year x int": {
#         "score": 0.08143894685440878,
#         "correlation": -0.2853750985184392
#     },
#     "Life Ladder x Log GDP Per Capita": {
#         "score": 0.9451529997905253,
#         "correlation": 0.9721897961769219
#     },
#     "Life Ladder x Social Support": {
#         "score": 0.9227305995987405,
#         "correlation": 0.9605886734699406
#     },
#     "Life Ladder x Healthy Life Expectancy At Birth": {
#         "score": 0.9475649849289783,
#         "correlation": 0.9734294966400894
#     },
#     "Life Ladder x Freedom To Make Life Choices": {
#         "score": 0.8177117571593072,
#         "correlation": 0.904274160395677
#     },
#     "Life Ladder x Generosity": {
#         "score": 0.05906379752881874,
#         "correlation": 0.24303044568287943
#     },
#     "Life Ladder x Perceptions Of Corruption": {
#         "score": 0.05599588852727799,
#         "correlation": 0.23663450409286876
#     },
#     "Life Ladder x Positive Affect": {
#         "score": 0.8289974915788076,
#         "correlation": 0.9104929937011088
#     },
#     "Life Ladder x Negative Affect": {
#         "score": 0.13907292407983796,
#         "correlation": 0.37292482363049784
#     },
#     "Life Ladder x Confidence In National Government": {
#         "score": 0.2047034457102257,
#         "correlation": 0.4524416489562226
#     },
#     "Life Ladder x int": {
#         "score": 0.008373962804150148,
#         "correlation": -0.09150935910686991
#     },
#     "Log GDP Per Capita x Social Support": {
#         "score": 0.6865377445906234,
#         "correlation": 0.8285757325619808
#     },
#     "Log GDP Per Capita x Healthy Life Expectancy At Birth": {
#         "score": 0.652267763720123,
#         "correlation": 0.8076309576286206
#     },
#     "Log GDP Per Capita x Freedom To Make Life Choices": {
#         "score": 0.6039892302733714,
#         "correlation": 0.7771674403070238
#     },
#     "Log GDP Per Capita x Generosity": {
#         "score": 0.05077856015338811,
#         "correlation": 0.2253409864036902
#     },
#     "Log GDP Per Capita x Perceptions Of Corruption": {
#         "score": 0.022328771724454355,
#         "correlation": -0.14942814903643287
#     },
#     "Log GDP Per Capita x Positive Affect": {
#         "score": 0.6535913413733464,
#         "correlation": 0.8084499621951542
#     },
#     "Log GDP Per Capita x Negative Affect": {
#         "score": 2.6327732334463505e-05,
#         "correlation": -0.005131055674468125
#     },
#     "Log GDP Per Capita x Confidence In National Government": {
#         "score": 0.04265273160433325,
#         "correlation": 0.2065253776278674
#     },
#     "Log GDP Per Capita x int": {
#         "score": 0.04177370646169276,
#         "correlation": -0.20438616993743136
#     },
#     "Social Support x Healthy Life Expectancy At Birth": {
#         "score": 0.681191890039857,
#         "correlation": 0.8253434982114155
#     },
#     "Social Support x Freedom To Make Life Choices": {
#         "score": 0.5697016197439833,
#         "correlation": 0.7547858105078441
#     },
#     "Social Support x Generosity": {
#         "score": 0.04653659251632092,
#         "correlation": 0.2157234167083422
#     },
#     "Social Support x Perceptions Of Corruption": {
#         "score": 0.01012949767600746,
#         "correlation": -0.10064540563785093
#     },
#     "Social Support x Positive Affect": {
#         "score": 0.5376540363764246,
#         "correlation": 0.7332489593422035
#     },
#     "Social Support x Negative Affect": {
#         "score": 0.004372279888422148,
#         "correlation": 0.06612321746876988
#     },
#     "Social Support x Confidence In National Government": {
#         "score": 0.04947044264889411,
#         "correlation": 0.22241951948714855
#     },
#     "Social Support x int": {
#         "score": 0.03564986010698479,
#         "correlation": -0.18881170542894013
#     },
#     "Healthy Life Expectancy At Birth x Freedom To Make Life Choices": {
#         "score": 0.5521502921883563,
#         "correlation": 0.7430681611994663
#     },
#     "Healthy Life Expectancy At Birth x Generosity": {
#         "score": 0.04645206711975958,
#         "correlation": 0.21552741616731655
#     },
#     "Healthy Life Expectancy At Birth x Perceptions Of Corruption": {
#         "score": 0.033228671162266465,
#         "correlation": -0.18228733132685473
#     },
#     "Healthy Life Expectancy At Birth x Positive Affect": {
#         "score": 0.586703394640185,
#         "correlation": 0.7659656615281034
#     },
#     "Healthy Life Expectancy At Birth x Negative Affect": {
#         "score": 0.0023838317386760677,
#         "correlation": -0.04882449936943801
#     },
#     "Healthy Life Expectancy At Birth x Confidence In National Government": {
#         "score": 0.02504755496366562,
#         "correlation": 0.15826419356147953
#     },
#     "Healthy Life Expectancy At Birth x int": {
#         "score": 0.047610858031902015,
#         "correlation": -0.21819912472762562
#     },
#     "Freedom To Make Life Choices x Generosity": {
#         "score": 0.04431462996006774,
#         "correlation": 0.21051040344854183
#     },
#     "Freedom To Make Life Choices x Perceptions Of Corruption": {
#         "score": 0.02344896392430984,
#         "correlation": -0.1531305453667226
#     },
#     "Freedom To Make Life Choices x Positive Affect": {
#         "score": 0.3729646297829503,
#         "correlation": 0.6107083017144522
#     },
#     "Freedom To Make Life Choices x Negative Affect": {
#         "score": 2.33851981967792e-06,
#         "correlation": -0.0015292219655240048
#     },
#     "Freedom To Make Life Choices x Confidence In National Government": {
#         "score": 0.01573341019924057,
#         "correlation": 0.12543289121773601
#     },
#     "Freedom To Make Life Choices x int": {
#         "score": 0.0466646953555655,
#         "correlation": -0.21602012720014213
#     },
#     "Generosity x Perceptions Of Corruption": {
#         "score": 0.011342407035013102,
#         "correlation": 0.10650073725102997
#     },
#     "Generosity x Positive Affect": {
#         "score": 0.038777494345616725,
#         "correlation": 0.1969200201747315
#     },
#     "Generosity x Negative Affect": {
#         "score": 0.024111729658143122,
#         "correlation": 0.15527952105201515
#     },
#     "Generosity x Confidence In National Government": {
#         "score": 0.02540316028774836,
#         "correlation": 0.15938368890118082
#     },
#     "Generosity x int": {
#         "score": 0.0001565264644894926,
#         "correlation": 0.012511053692218537
#     },
#     "Perceptions Of Corruption x Positive Affect": {
#         "score": 0.03417417778326193,
#         "correlation": -0.18486259162757068
#     },
#     "Perceptions Of Corruption x Negative Affect": {
#         "score": 0.20780172912511896,
#         "correlation": -0.4558527493885705
#     },
#     "Perceptions Of Corruption x Confidence In National Government": {
#         "score": 0.17779941664488175,
#         "correlation": -0.4216626811147528
#     },
#     "Perceptions Of Corruption x int": {
#         "score": 0.1328915672297406,
#         "correlation": -0.36454295663164404
#     },
#     "Positive Affect x Negative Affect": {
#         "score": 0.0007570535037271231,
#         "correlation": -0.02751460528023541
#     },
#     "Positive Affect x Confidence In National Government": {
#         "score": 0.013873168214451614,
#         "correlation": 0.11778441414063084
#     },
#     "Positive Affect x int": {
#         "score": 0.04957783915891356,
#         "correlation": -0.22266081639775176
#     },
#     "Negative Affect x Confidence In National Government": {
#         "score": 0.07167820481887677,
#         "correlation": -0.2677278558889174
#     },
#     "Negative Affect x int": {
#         "score": 0.08344174071251209,
#         "correlation": -0.28886284065713963
#     },
#     "Confidence In National Government x int": {
#         "score": 0.06933387609377761,
#         "correlation": -0.26331326608011535
#     }
# }

# %%
for key in score_dict.keys():
    score_dict[key].update({"combined": np.average(
        [score_dict[key]["score"], score_dict[key]["correlation"]])}
    )

print(json.dumps(score_dict, indent=4))
# Out:
# {
#     "Year": {
#         "score": 0.0051478832185841705,
#         "correlation": 0.07174875064127634,
#         "combined": 0.038448316929930254
#     },
#     "Life Ladder": {
#         "score": 1.0,
#         "correlation": 1.0,
#         "combined": 1.0
#     },
#     "Log GDP Per Capita": {
#         "score": 0.6281698077144784,
#         "correlation": 0.7925716420075085,
#         "combined": 0.7103707248609934
#     },
#     "Social Support": {
#         "score": 0.5192853987535683,
#         "correlation": 0.7206145979326039,
#         "combined": 0.6199499983430861
#     },
#     "Healthy Life Expectancy At Birth": {
#         "score": 0.5404614758255641,
#         "correlation": 0.7351608503079881,
#         "combined": 0.6378111630667761
#     },
#     "Freedom To Make Life Choices": {
#         "score": 0.2940861329423261,
#         "correlation": 0.5422970891885057,
#         "combined": 0.4181916110654159
#     },
#     "Generosity": {
#         "score": 0.03753479127663817,
#         "correlation": 0.1937389771745434,
#         "combined": 0.11563688422559078
#     },
#     "Perceptions Of Corruption": {
#         "score": 0.24222475409085542,
#         "correlation": -0.49216334086444846,
#         "combined": -0.12496929338679652
#     },
#     "Positive Affect": {
#         "score": 0.26300717570566623,
#         "correlation": 0.5128422522624927,
#         "combined": 0.38792471398407946
#     },
#     "Negative Affect": {
#         "score": 0.09594787291010276,
#         "correlation": -0.3097545365448305,
#         "combined": -0.10690333181736386
#     },
#     "Confidence In National Government": {
#         "score": 0.0047124322248692785,
#         "correlation": -0.0686471574420167,
#         "combined": -0.03196736260857371
#     },
#     "int": {
#         "score": 0.08155250752791565,
#         "correlation": -0.28557399658917776,
#         "combined": -0.10201074453063105
#     },
#     "Year x Life Ladder": {
#         "score": 0.9998865402394389,
#         "correlation": 0.9999432685104888,
#         "combined": 0.9999149043749638
#     },
#     "Year x Log GDP Per Capita": {
#         "score": 0.6277278908179801,
#         "correlation": 0.7922928062389435,
#         "combined": 0.7100103485284618
#     },
#     "Year x Social Support": {
#         "score": 0.5207470851330853,
#         "correlation": 0.7216280795070857,
#         "combined": 0.6211875823200855
#     },
#     "Year x Healthy Life Expectancy At Birth": {
#         "score": 0.5388578409747056,
#         "correlation": 0.7340693706828433,
#         "combined": 0.6364636058287745
#     },
#     "Year x Freedom To Make Life Choices": {
#         "score": 0.293381458279405,
#         "correlation": 0.5416469867722011,
#         "combined": 0.41751422252580306
#     },
#     "Year x Generosity": {
#         "score": 0.03746313986111449,
#         "correlation": 0.19355397144237216,
#         "combined": 0.11550855565174332
#     },
#     "Year x Perceptions Of Corruption": {
#         "score": 0.24197590567307103,
#         "correlation": -0.4919104650981427,
#         "combined": -0.12496727971253582
#     },
#     "Year x Positive Affect": {
#         "score": 0.2638460798800476,
#         "correlation": 0.5136594979945837,
#         "combined": 0.38875278893731563
#     },
#     "Year x Negative Affect": {
#         "score": 0.09544999676760724,
#         "correlation": -0.3089498288842497,
#         "combined": -0.10674991605832124
#     },
#     "Year x Confidence In National Government": {
#         "score": 0.0046634937229093065,
#         "correlation": -0.06828977758720077,
#         "combined": -0.03181314193214573
#     },
#     "Year x int": {
#         "score": 0.08143894685440878,
#         "correlation": -0.2853750985184392,
#         "combined": -0.1019680758320152
#     },
#     "Life Ladder x Log GDP Per Capita": {
#         "score": 0.9451529997905253,
#         "correlation": 0.9721897961769219,
#         "combined": 0.9586713979837236
#     },
#     "Life Ladder x Social Support": {
#         "score": 0.9227305995987405,
#         "correlation": 0.9605886734699406,
#         "combined": 0.9416596365343406
#     },
#     "Life Ladder x Healthy Life Expectancy At Birth": {
#         "score": 0.9475649849289783,
#         "correlation": 0.9734294966400894,
#         "combined": 0.9604972407845338
#     },
#     "Life Ladder x Freedom To Make Life Choices": {
#         "score": 0.8177117571593072,
#         "correlation": 0.904274160395677,
#         "combined": 0.860992958777492
#     },
#     "Life Ladder x Generosity": {
#         "score": 0.05906379752881874,
#         "correlation": 0.24303044568287943,
#         "combined": 0.1510471216058491
#     },
#     "Life Ladder x Perceptions Of Corruption": {
#         "score": 0.05599588852727799,
#         "correlation": 0.23663450409286876,
#         "combined": 0.1463151963100734
#     },
#     "Life Ladder x Positive Affect": {
#         "score": 0.8289974915788076,
#         "correlation": 0.9104929937011088,
#         "combined": 0.8697452426399582
#     },
#     "Life Ladder x Negative Affect": {
#         "score": 0.13907292407983796,
#         "correlation": 0.37292482363049784,
#         "combined": 0.2559988738551679
#     },
#     "Life Ladder x Confidence In National Government": {
#         "score": 0.2047034457102257,
#         "correlation": 0.4524416489562226,
#         "combined": 0.32857254733322416
#     },
#     "Life Ladder x int": {
#         "score": 0.008373962804150148,
#         "correlation": -0.09150935910686991,
#         "combined": -0.04156769815135988
#     },
#     "Log GDP Per Capita x Social Support": {
#         "score": 0.6865377445906234,
#         "correlation": 0.8285757325619808,
#         "combined": 0.7575567385763021
#     },
#     "Log GDP Per Capita x Healthy Life Expectancy At Birth": {
#         "score": 0.652267763720123,
#         "correlation": 0.8076309576286206,
#         "combined": 0.7299493606743718
#     },
#     "Log GDP Per Capita x Freedom To Make Life Choices": {
#         "score": 0.6039892302733714,
#         "correlation": 0.7771674403070238,
#         "combined": 0.6905783352901975
#     },
#     "Log GDP Per Capita x Generosity": {
#         "score": 0.05077856015338811,
#         "correlation": 0.2253409864036902,
#         "combined": 0.13805977327853916
#     },
#     "Log GDP Per Capita x Perceptions Of Corruption": {
#         "score": 0.022328771724454355,
#         "correlation": -0.14942814903643287,
#         "combined": -0.06354968865598926
#     },
#     "Log GDP Per Capita x Positive Affect": {
#         "score": 0.6535913413733464,
#         "correlation": 0.8084499621951542,
#         "combined": 0.7310206517842504
#     },
#     "Log GDP Per Capita x Negative Affect": {
#         "score": 2.6327732334463505e-05,
#         "correlation": -0.005131055674468125,
#         "combined": -0.002552363971066831
#     },
#     "Log GDP Per Capita x Confidence In National Government": {
#         "score": 0.04265273160433325,
#         "correlation": 0.2065253776278674,
#         "combined": 0.12458905461610033
#     },
#     "Log GDP Per Capita x int": {
#         "score": 0.04177370646169276,
#         "correlation": -0.20438616993743136,
#         "combined": -0.0813062317378693
#     },
#     "Social Support x Healthy Life Expectancy At Birth": {
#         "score": 0.681191890039857,
#         "correlation": 0.8253434982114155,
#         "combined": 0.7532676941256362
#     },
#     "Social Support x Freedom To Make Life Choices": {
#         "score": 0.5697016197439833,
#         "correlation": 0.7547858105078441,
#         "combined": 0.6622437151259137
#     },
#     "Social Support x Generosity": {
#         "score": 0.04653659251632092,
#         "correlation": 0.2157234167083422,
#         "combined": 0.13113000461233154
#     },
#     "Social Support x Perceptions Of Corruption": {
#         "score": 0.01012949767600746,
#         "correlation": -0.10064540563785093,
#         "combined": -0.045257953980921736
#     },
#     "Social Support x Positive Affect": {
#         "score": 0.5376540363764246,
#         "correlation": 0.7332489593422035,
#         "combined": 0.635451497859314
#     },
#     "Social Support x Negative Affect": {
#         "score": 0.004372279888422148,
#         "correlation": 0.06612321746876988,
#         "combined": 0.035247748678596015
#     },
#     "Social Support x Confidence In National Government": {
#         "score": 0.04947044264889411,
#         "correlation": 0.22241951948714855,
#         "combined": 0.13594498106802133
#     },
#     "Social Support x int": {
#         "score": 0.03564986010698479,
#         "correlation": -0.18881170542894013,
#         "combined": -0.07658092266097767
#     },
#     "Healthy Life Expectancy At Birth x Freedom To Make Life Choices": {
#         "score": 0.5521502921883563,
#         "correlation": 0.7430681611994663,
#         "combined": 0.6476092266939113
#     },
#     "Healthy Life Expectancy At Birth x Generosity": {
#         "score": 0.04645206711975958,
#         "correlation": 0.21552741616731655,
#         "combined": 0.13098974164353805
#     },
#     "Healthy Life Expectancy At Birth x Perceptions Of Corruption": {
#         "score": 0.033228671162266465,
#         "correlation": -0.18228733132685473,
#         "combined": -0.07452933008229413
#     },
#     "Healthy Life Expectancy At Birth x Positive Affect": {
#         "score": 0.586703394640185,
#         "correlation": 0.7659656615281034,
#         "combined": 0.6763345280841442
#     },
#     "Healthy Life Expectancy At Birth x Negative Affect": {
#         "score": 0.0023838317386760677,
#         "correlation": -0.04882449936943801,
#         "combined": -0.02322033381538097
#     },
#     "Healthy Life Expectancy At Birth x Confidence In National Government": {
#         "score": 0.02504755496366562,
#         "correlation": 0.15826419356147953,
#         "combined": 0.09165587426257257
#     },
#     "Healthy Life Expectancy At Birth x int": {
#         "score": 0.047610858031902015,
#         "correlation": -0.21819912472762562,
#         "combined": -0.0852941333478618
#     },
#     "Freedom To Make Life Choices x Generosity": {
#         "score": 0.04431462996006774,
#         "correlation": 0.21051040344854183,
#         "combined": 0.12741251670430478
#     },
#     "Freedom To Make Life Choices x Perceptions Of Corruption": {
#         "score": 0.02344896392430984,
#         "correlation": -0.1531305453667226,
#         "combined": -0.06484079072120638
#     },
#     "Freedom To Make Life Choices x Positive Affect": {
#         "score": 0.3729646297829503,
#         "correlation": 0.6107083017144522,
#         "combined": 0.49183646574870127
#     },
#     "Freedom To Make Life Choices x Negative Affect": {
#         "score": 2.33851981967792e-06,
#         "correlation": -0.0015292219655240048,
#         "combined": -0.0007634417228521634
#     },
#     "Freedom To Make Life Choices x Confidence In National Government": {
#         "score": 0.01573341019924057,
#         "correlation": 0.12543289121773601,
#         "combined": 0.0705831507084883
#     },
#     "Freedom To Make Life Choices x int": {
#         "score": 0.0466646953555655,
#         "correlation": -0.21602012720014213,
#         "combined": -0.08467771592228832
#     },
#     "Generosity x Perceptions Of Corruption": {
#         "score": 0.011342407035013102,
#         "correlation": 0.10650073725102997,
#         "combined": 0.05892157214302154
#     },
#     "Generosity x Positive Affect": {
#         "score": 0.038777494345616725,
#         "correlation": 0.1969200201747315,
#         "combined": 0.11784875726017412
#     },
#     "Generosity x Negative Affect": {
#         "score": 0.024111729658143122,
#         "correlation": 0.15527952105201515,
#         "combined": 0.08969562535507913
#     },
#     "Generosity x Confidence In National Government": {
#         "score": 0.02540316028774836,
#         "correlation": 0.15938368890118082,
#         "combined": 0.09239342459446459
#     },
#     "Generosity x int": {
#         "score": 0.0001565264644894926,
#         "correlation": 0.012511053692218537,
#         "combined": 0.006333790078354015
#     },
#     "Perceptions Of Corruption x Positive Affect": {
#         "score": 0.03417417778326193,
#         "correlation": -0.18486259162757068,
#         "combined": -0.07534420692215438
#     },
#     "Perceptions Of Corruption x Negative Affect": {
#         "score": 0.20780172912511896,
#         "correlation": -0.4558527493885705,
#         "combined": -0.12402551013172577
#     },
#     "Perceptions Of Corruption x Confidence In National Government": {
#         "score": 0.17779941664488175,
#         "correlation": -0.4216626811147528,
#         "combined": -0.12193163223493553
#     },
#     "Perceptions Of Corruption x int": {
#         "score": 0.1328915672297406,
#         "correlation": -0.36454295663164404,
#         "combined": -0.11582569470095172
#     },
#     "Positive Affect x Negative Affect": {
#         "score": 0.0007570535037271231,
#         "correlation": -0.02751460528023541,
#         "combined": -0.013378775888254143
#     },
#     "Positive Affect x Confidence In National Government": {
#         "score": 0.013873168214451614,
#         "correlation": 0.11778441414063084,
#         "combined": 0.06582879117754123
#     },
#     "Positive Affect x int": {
#         "score": 0.04957783915891356,
#         "correlation": -0.22266081639775176,
#         "combined": -0.0865414886194191
#     },
#     "Negative Affect x Confidence In National Government": {
#         "score": 0.07167820481887677,
#         "correlation": -0.2677278558889174,
#         "combined": -0.09802482553502032
#     },
#     "Negative Affect x int": {
#         "score": 0.08344174071251209,
#         "correlation": -0.28886284065713963,
#         "combined": -0.10271054997231377
#     },
#     "Confidence In National Government x int": {
#         "score": 0.06933387609377761,
#         "correlation": -0.26331326608011535,
#         "combined": -0.09698969499316887
#     }
# }

# %%
keys = list(score_dict.keys())
values = [score["combined"] for score in score_dict.values()]
sorted_value_index = np.argsort(values)[::-1]
sorted_dict = {keys[i]: values[i] for i in sorted_value_index}
 
print(json.dumps(sorted_dict, indent=4))
# Out:
# {
#     "Life Ladder": 1.0,
#     "Year x Life Ladder": 0.9999149043749638,
#     "Life Ladder x Healthy Life Expectancy At Birth": 0.9604972407845338,
#     "Life Ladder x Log GDP Per Capita": 0.9586713979837236,
#     "Life Ladder x Social Support": 0.9416596365343406,
#     "Life Ladder x Positive Affect": 0.8697452426399582,
#     "Life Ladder x Freedom To Make Life Choices": 0.860992958777492,
#     "Log GDP Per Capita x Social Support": 0.7575567385763021,
#     "Social Support x Healthy Life Expectancy At Birth": 0.7532676941256362,
#     "Log GDP Per Capita x Positive Affect": 0.7310206517842504,
#     "Log GDP Per Capita x Healthy Life Expectancy At Birth": 0.7299493606743718,
#     "Log GDP Per Capita": 0.7103707248609934,
#     "Year x Log GDP Per Capita": 0.7100103485284618,
#     "Log GDP Per Capita x Freedom To Make Life Choices": 0.6905783352901975,
#     "Healthy Life Expectancy At Birth x Positive Affect": 0.6763345280841442,
#     "Social Support x Freedom To Make Life Choices": 0.6622437151259137,
#     "Healthy Life Expectancy At Birth x Freedom To Make Life Choices": 0.6476092266939113,
#     "Healthy Life Expectancy At Birth": 0.6378111630667761,
#     "Year x Healthy Life Expectancy At Birth": 0.6364636058287745,
#     "Social Support x Positive Affect": 0.635451497859314,
#     "Year x Social Support": 0.6211875823200855,
#     "Social Support": 0.6199499983430861,
#     "Freedom To Make Life Choices x Positive Affect": 0.49183646574870127,
#     "Freedom To Make Life Choices": 0.4181916110654159,
#     "Year x Freedom To Make Life Choices": 0.41751422252580306,
#     "Year x Positive Affect": 0.38875278893731563,
#     "Positive Affect": 0.38792471398407946,
#     "Life Ladder x Confidence In National Government": 0.32857254733322416,
#     "Life Ladder x Negative Affect": 0.2559988738551679,
#     "Life Ladder x Generosity": 0.1510471216058491,
#     "Life Ladder x Perceptions Of Corruption": 0.1463151963100734,
#     "Log GDP Per Capita x Generosity": 0.13805977327853916,
#     "Social Support x Confidence In National Government": 0.13594498106802133,
#     "Social Support x Generosity": 0.13113000461233154,
#     "Healthy Life Expectancy At Birth x Generosity": 0.13098974164353805,
#     "Freedom To Make Life Choices x Generosity": 0.12741251670430478,
#     "Log GDP Per Capita x Confidence In National Government": 0.12458905461610033,
#     "Generosity x Positive Affect": 0.11784875726017412,
#     "Generosity": 0.11563688422559078,
#     "Year x Generosity": 0.11550855565174332,
#     "Generosity x Confidence In National Government": 0.09239342459446459,
#     "Healthy Life Expectancy At Birth x Confidence In National Government": 0.09165587426257257,
#     "Generosity x Negative Affect": 0.08969562535507913,
#     "Freedom To Make Life Choices x Confidence In National Government": 0.0705831507084883,
#     "Positive Affect x Confidence In National Government": 0.06582879117754123,
#     "Generosity x Perceptions Of Corruption": 0.05892157214302154,
#     "Year": 0.038448316929930254,
#     "Social Support x Negative Affect": 0.035247748678596015,
#     "Generosity x int": 0.006333790078354015,
#     "Freedom To Make Life Choices x Negative Affect": -0.0007634417228521634,
#     "Log GDP Per Capita x Negative Affect": -0.002552363971066831,
#     "Positive Affect x Negative Affect": -0.013378775888254143,
#     "Healthy Life Expectancy At Birth x Negative Affect": -0.02322033381538097,
#     "Year x Confidence In National Government": -0.03181314193214573,
#     "Confidence In National Government": -0.03196736260857371,
#     "Life Ladder x int": -0.04156769815135988,
#     "Social Support x Perceptions Of Corruption": -0.045257953980921736,
#     "Log GDP Per Capita x Perceptions Of Corruption": -0.06354968865598926,
#     "Freedom To Make Life Choices x Perceptions Of Corruption": -0.06484079072120638,
#     "Healthy Life Expectancy At Birth x Perceptions Of Corruption": -0.07452933008229413,
#     "Perceptions Of Corruption x Positive Affect": -0.07534420692215438,
#     "Social Support x int": -0.07658092266097767,
#     "Log GDP Per Capita x int": -0.0813062317378693,
#     "Freedom To Make Life Choices x int": -0.08467771592228832,
#     "Healthy Life Expectancy At Birth x int": -0.0852941333478618,
#     "Positive Affect x int": -0.0865414886194191,
#     "Confidence In National Government x int": -0.09698969499316887,
#     "Negative Affect x Confidence In National Government": -0.09802482553502032,
#     "Year x int": -0.1019680758320152,
#     "int": -0.10201074453063105,
#     "Negative Affect x int": -0.10271054997231377,
#     "Year x Negative Affect": -0.10674991605832124,
#     "Negative Affect": -0.10690333181736386,
#     "Perceptions Of Corruption x int": -0.11582569470095172,
#     "Perceptions Of Corruption x Confidence In National Government": -0.12193163223493553,
#     "Perceptions Of Corruption x Negative Affect": -0.12402551013172577,
#     "Year x Perceptions Of Corruption": -0.12496727971253582,
#     "Perceptions Of Corruption": -0.12496929338679652
# }

# %% [markdown]
# maybe we can try these variables?

# %%
train_df, test_df = train_test_split(numbers_df, test_size=0.75, random_state=58)

# %%
new_columns = [
    "Log GDP Per Capita x Social Support",
    "Healthy Life Expectancy At Birth x Positive Affect",
    "Freedom To Make Life Choices"
]

# %%
new_model = train_model(train_df, new_columns)
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            Life Ladder   R-squared (uncentered):                   0.990
# Model:                            OLS   Adj. R-squared (uncentered):              0.990
# Method:                 Least Squares   F-statistic:                          1.326e+04
# Date:                Fri, 19 May 2023   Prob (F-statistic):                        0.00
# Time:                        18:48:20   Log-Likelihood:                         -359.44
# No. Observations:                 420   AIC:                                      724.9
# Df Residuals:                     417   BIC:                                      737.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Log GDP Per Capita x Social Support                    0.3636      0.020     18.050      0.000       0.324       0.403
# Healthy Life Expectancy At Birth x Positive Affect     0.0457      0.005      9.164      0.000       0.036       0.055
# Freedom To Make Life Choices                           1.0147      0.216      4.704      0.000       0.591       1.439
# ==============================================================================
# Omnibus:                       30.096   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.177
# Skew:                           0.387   Prob(JB):                     7.03e-15
# Kurtosis:                       4.768   Cond. No.                         336.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
predict_df = test_model(train_df, new_columns, new_model)

print("RMSE:", compute_rmse(predict_df))
print("Correlation:", predict_df["Life Ladder"].corr(predict_df["predicted_life_ladder"]))
# Out:
# RMSE: 0.5694230055432464
# Correlation: 0.8735477061676316

# %% [markdown]
# We see that we bumped up the correlation to 87%, even better! And the RSME went down too!
